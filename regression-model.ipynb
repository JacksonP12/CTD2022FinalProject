# %%
#carbon emissions data (modified from million metric tons to metric tons): https://www.eia.gov/environment/emissions/state/
#transportation data: https://www.apta.com/research-technical-resources/transit-statistics/
#population data: https://www.census.gov/newsroom/press-kits/2018/pop-estimates-national-state.html
#land area data: https://www.census.gov/geographies/reference-files/2010/geo/state-area.html
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import processed state data
df = pd.read_csv('processed data.csv')

# %%
#describe data
df.describe()
# Out:
#        Vehicle Revenue Miles  Carbon Emissions (Metric Tons)    Population  \
# count           5.000000e+01                    5.000000e+01  5.000000e+01
# mean            9.255008e+07                    1.058389e+08  6.529300e+06
# std             1.486542e+08                    1.100388e+08  7.371930e+06
# min             3.760507e+06                    5.854280e+06  5.777370e+05
# 25%             1.638316e+07                    4.250078e+07  1.836691e+06
# 50%             4.108476e+07                    8.054306e+07  4.564190e+06
# 75%             9.751818e+07                    1.238524e+08  7.444605e+06
# max             7.595542e+08                    6.846896e+08  3.955704e+07
#
#            Land Area
# count      50.000000
# mean    70636.920000
# std     85815.683884
# min      1034.000000
# 25%     36741.000000
# 50%     53891.500000
# 75%     81226.000000
# max    570641.000000

# %%
import statsmodels.api as sm #stats package
import numpy as np

X = df[['Vehicle Revenue Miles', 'Population', 'Land Area']] #independent variables
y = df['Carbon Emissions (Metric Tons)'] #dependent variable, metric tons of carbon emissions

X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ...
# Dep. Variable:     Carbon Emissions (Metric Tons)   R-squared:                       0.788
# Model:                                        OLS   Adj. R-squared:                  0.774
# Method:                             Least Squares   F-statistic:                     56.83
# Date:                            Wed, 13 Jul 2022   Prob (F-statistic):           1.66e-15
# Time:                                    13:32:28   Log-Likelihood:                -957.54
# No. Observations:                              50   AIC:                             1923.
# Df Residuals:                                  46   BIC:                             1931.
# Df Model:                                       3
# Covariance Type:                        nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Carbon Emissions (Metric Tons) = 10400000 - 0.3676(Vehicle Revenue Miles) + 18.6294(Population) + 110.7654(Land Area)

# %%
#TEST EXAMPLE: Washington
#Expected CE: 10400000 - 0.3676(175278128) + 18.6294(7535591) + 110.7654(66456) = 10400000 - 64432239.8528 + 140383538.975 + 7361025.4224
#93,712,324
#Actual CE:
#78,658,554
